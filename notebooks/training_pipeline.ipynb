# %% [markdown]
# type:Markdown
# # Supply Chain Disruption Early Warning System
# This notebook will fetch GDELT data, build features, train a model and log results to DagsHub and Neon.

# %%
print("Notebook successfully created — ready for pipeline code!")
# Out:
# Notebook successfully created — ready for pipeline code!

# %%
! pip install pandas==2.2.3 sqlalchemy==2.0.35 psycopg2-binary==2.9.9 scikit-learn==1.7.2 mlflow==3.5.1 requests==2.32.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==2.2.3
#   Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting sqlalchemy==2.0.35
#   Downloading SQLAlchemy-2.0.35-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting psycopg2-binary==2.9.9
#   Downloading psycopg2_binary-2.9.9-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Collecting scikit-learn==1.7.2
#   Downloading scikit_learn-1.7.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting mlflow==3.5.1
#   Downloading mlflow-3.5.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests==2.32.3 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas==2.2.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas==2.2.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas==2.2.3) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy==2.0.35) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy==2.0.35) (3.0.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn==1.7.2) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn==1.7.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn==1.7.2) (3.5.0)
# Collecting mlflow-skinny==3.5.1 (from mlflow==3.5.1)
#   Downloading mlflow_skinny-3.5.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.5.1 (from mlflow==3.5.1)
#   Downloading mlflow_tracing-3.5.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow==3.5.1)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow==3.5.1)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow==3.5.1)
#   Downloading alembic-1.17.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting cryptography<47,>=43.0.0 (from mlflow==3.5.1)
#   Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow==3.5.1)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow==3.5.1)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib<4 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow==3.5.1) (3.9.2)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow==3.5.1) (17.0.0)
# Collecting waitress<4 (from mlflow==3.5.1)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests==2.32.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests==2.32.3) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests==2.32.3) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests==2.32.3) (2024.8.30)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1) (8.1.7)
# Collecting cloudpickle<4 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading databricks_sdk-0.73.0-py3-none-any.whl.metadata (40 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading fastapi-0.121.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1) (3.1.43)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1) (24.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1) (5.28.0)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1) (2.9.1)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlflow-skinny==3.5.1->mlflow==3.5.1) (6.0.2)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Using cached sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting uvicorn<1 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==3.5.1)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting cffi>=2.0.0 (from cryptography<47,>=43.0.0->mlflow==3.5.1)
#   Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from docker<8,>=4.0.0->mlflow==3.5.1) (306)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow==3.5.1)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow==3.5.1)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask<4->mlflow==3.5.1) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Flask<4->mlflow==3.5.1) (2.1.5)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow==3.5.1)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow==3.5.1)
#   Downloading graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow==3.5.1)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow==3.5.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow==3.5.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow==3.5.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow==3.5.1) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow==3.5.1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib<4->mlflow==3.5.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow==3.5.1) (2.22)
# Requirement already satisfied: colorama in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click<9,>=7.0->mlflow-skinny==3.5.1->mlflow==3.5.1) (0.4.6)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting starlette<0.50.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading starlette-0.49.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading annotated_doc-0.0.3-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow==3.5.1) (4.0.11)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow==3.5.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow==3.5.1) (2.23.3)
# Requirement already satisfied: h11>=0.8 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn<1->mlflow-skinny==3.5.1->mlflow==3.5.1) (0.14.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow==3.5.1) (5.0.1)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.5.1->mlflow==3.5.1) (4.4.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sec\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.5.1->mlflow==3.5.1) (1.3.1)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow==3.5.1)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 598.5 kB/s eta 0:00:19
#    -- ------------------------------------- 0.8/11.5 MB 817.9 kB/s eta 0:00:14
#    -- ------------------------------------- 0.8/11.5 MB 817.9 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/11.5 MB 739.8 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.3/11.5 MB 818.6 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.6/11.5 MB 873.8 kB/s eta 0:00:12
#    ------ --------------------------------- 1.8/11.5 MB 853.0 kB/s eta 0:00:12
#    ------ --------------------------------- 1.8/11.5 MB 853.0 kB/s eta 0:00:12
#    ------- -------------------------------- 2.1/11.5 MB 815.6 kB/s eta 0:00:12
#    -------- ------------------------------- 2.4/11.5 MB 844.3 kB/s eta 0:00:11
#    --------- ------------------------------ 2.6/11.5 MB 877.7 kB/s eta 0:00:11
#    ---------- ----------------------------- 2.9/11.5 MB 902.1 kB/s eta 0:00:10
#    ---------- ----------------------------- 3.1/11.5 MB 932.0 kB/s eta 0:00:09
#    ----------- ---------------------------- 3.4/11.5 MB 972.7 kB/s eta 0:00:09
#    ------------ --------------------------- 3.7/11.5 MB 952.5 kB/s eta 0:00:09
#    ------------- -------------------------- 3.9/11.5 MB 986.8 kB/s eta 0:00:08
#    -------------- ------------------------- 4.2/11.5 MB 1.0 MB/s eta 0:00:08
#    --------------- ------------------------ 4.5/11.5 MB 1.0 MB/s eta 0:00:07
#    --------------- ------------------------ 4.5/11.5 MB 1.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 4.7/11.5 MB 966.9 kB/s eta 0:00:08
#    ---------------- ----------------------- 4.7/11.5 MB 966.9 kB/s eta 0:00:08
#    ---------------- ----------------------- 4
MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.8 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  8.7/8.8 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.8/8.8 MB 2.4 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.5.1-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ------------------ --------------------- 1.0/2.3 MB 2.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 2.6 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.5.1-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------- ----------------------- 0.5/1.3 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 2.8 MB/s eta 0:00:00
# Downloading alembic-1.17.1-py3-none-any.whl (247 kB)
# Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading databricks_sdk-0.73.0-py3-none-any.whl (753 kB)
#    ---------------------------------------- 0.0/753.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/753.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/753.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/753.9 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/753.9 kB ? eta -:--:--
#    ---------------------------------------- 753.9/753.9 kB 2.1 MB/s eta 0:00:00
# Downloading fastapi-0.121.0-py3-none-any.whl (109 kB)
# Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
# Downloading protobuf-6.33.0-cp310-abi3-win_amd64.whl (436 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading annotated_doc-0.0.3-py3-none-any.whl (5.5 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: zipp, werkzeug, waitress, sqlparse, sqlalchemy, python-dotenv, pyasn1, psycopg2-binary, protobuf, Mako, itsdangerous, graphql-core, cloudpickle, cffi, blinker, annotated-doc, uvicorn, starlette, scikit-learn, rsa, pyasn1-modules, pandas, opentelemetry-proto, importlib_metadata, graphql-relay, Flask, docker, cryptography, alembic, opentelemetry-api, graphene, google-auth, Flask-CORS, fastapi, opentelemetry-semantic-conventions, databricks-sdk, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.34
#     Uninstalling SQLAlchemy-2.0.34:
#       Successfully uninstalled SQLAlchemy-2.0.34
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.0
#     Uninstalling protobuf-5.28.0:
#       Successfully uninstalled protobuf-5.28.0
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.17.1
#     Uninstalling cffi-1.17.1:
#       Successfully uninstalled cffi-1.17.1
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.8.2
#     Uninstalling blinker-1.8.2:
#       Successfully uninstalled blinker-1.8.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.1 annotated-doc-0.0.3 blinker-1.9.0 cffi-2.0.0 cloudpickle-3.1.2 cryptography-46.0.3 databricks-sdk-0.73.0 docker-7.1.0 fastapi-0.121.0 google-auth-2.43.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 importlib_metadata-8.7.0 itsdangerous-2.2.0 mlflow-3.5.1 mlflow-skinny-3.5.1 mlflow-tracing-3.5.1 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pandas-2.2.3 protobuf-6.33.0 psycopg2-binary-2.9.9 pyasn1-0.6.1 pyasn1-modules-0.4.2 python-dotenv-1.2.1 rsa-4.9.1 scikit-learn-1.7.2 sqlalchemy-2.0.35 sqlparse-0.5.3 starlette-0.49.3 uvicorn-0.38.0 waitress-3.0.2 werkzeug-3.1.3 zipp-3.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.38.0 requires protobuf<6,>=3.20, but you have protobuf 6.33.0 which is incompatible.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\SEC\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd
import numpy as np
import requests
from sqlalchemy import create_engine
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import average_precision_score, brier_score_loss
import mlflow

# ---- configuration ----
# Replace with your own Neon + DagsHub values
DATABASE_URL = "postgresql+psycopg2://neondb_owner:npg_k5JYXPoFzM1N@ep-wandering-salad-a1c7264o-pooler.ap-southeast-1.aws.neon.tech/neondb?sslmode=require"
MLFLOW_URI   = "https://dagshub.com/Yuvakrishna0/Supplychainprediction.mlflow/"              # from DagsHub

# local MLflow tracking (fallback)
os.environ["MLFLOW_TRACKING_URI"] = MLFLOW_URI

# %%
import pandas as pd, numpy as np
from datetime import date, timedelta

print("Generating local synthetic GDELT-like dataset...")

# make 30 days of events
dates = pd.date_range(date.today() - timedelta(days=30), periods=30)
countries = ["USA", "IND", "CHN", "DEU", "BRA", "GBR", "JPN", "AUS"]

gdelt = pd.DataFrame({
    "SQLDATE": [d.strftime("%Y%m%d") for d in dates],
    "AvgTone": np.random.normal(0, 3, len(dates)),       # sentiment tone
    "ActionGeo_CountryCode": np.random.choice(countries, len(dates))
})

gdelt["event_time"] = pd.to_datetime(gdelt["SQLDATE"], format="%Y%m%d")
print("✅ Synthetic data created:", gdelt.shape)
display(gdelt.head())
# Out:
# Generating local synthetic GDELT-like dataset...
# ✅ Synthetic data created: (30, 4)
#     SQLDATE   AvgTone ActionGeo_CountryCode event_time
# 0  20251007 -2.751545                   IND 2025-10-07
# 1  20251008  2.025211                   CHN 2025-10-08
# 2  20251009 -0.341316                   CHN 2025-10-09
# 3  20251010  1.932428                   JPN 2025-10-10
# 4  20251011 -0.800994                   CHN 2025-10-11

# %%
# aggregate tone by date
gdelt["ds"] = gdelt["event_time"].dt.date
features = (
    gdelt.groupby("ds", as_index=False)
         .agg(gdelt_tone_mean=("AvgTone","mean"),
              gdelt_tone_std=("AvgTone","std"))
)

# simulate a simple 'congestion' proxy
np.random.seed(42)
features["port_congestion_z"] = np.random.normal(0, 1, len(features))

# label: random high congestion as disruptions
threshold = 1.2
features["label_bottleneck_next_14d"] = (features["port_congestion_z"] > threshold).astype(int)

features.tail()
# Out:
#             ds  gdelt_tone_mean  gdelt_tone_std  port_congestion_z  \
# 25  2025-11-01        -0.088389             NaN           0.110923
# 26  2025-11-02         1.116156             NaN          -1.150994
# 27  2025-11-03         4.328073             NaN           0.375698
# 28  2025-11-04        -4.814605             NaN          -0.600639
# 29  2025-11-05         2.998178             NaN          -0.291694
#
#     label_bottleneck_next_14d
# 25                          0
# 26                          0
# 27                          0
# 28                          0
# 29                          0

# %%
mlflow.set_tracking_uri(MLFLOW_URI)
import mlflow
import os

# Your DagsHub credentials (replace with your actual username + token)
DAGSHUB_USERNAME = "Yuvakrishna0"  # <-- your DagsHub username
DAGSHUB_TOKEN = "b6507130bc00540377098c15b7a707b463896e35"  # from DagsHub settings

os.environ["MLFLOW_TRACKING_USERNAME"] = DAGSHUB_USERNAME
os.environ["MLFLOW_TRACKING_PASSWORD"] = DAGSHUB_TOKEN

# Now connect to your DagsHub MLflow server
mlflow.set_tracking_uri(f"https://dagshub.com/{DAGSHUB_USERNAME}/Supplychainprediction.mlflow")
mlflow.set_experiment("Supplychainprediction")

print("✅ Connected to DagsHub MLflow successfully.")
# Out:
# 2025/11/06 19:14:29 INFO mlflow.tracking.fluent: Experiment with name 'Supplychainprediction' does not exist. Creating a new experiment.
# ✅ Connected to DagsHub MLflow successfully.

# %%
engine = create_engine(DATABASE_URL)
features.to_sql("features_supply_risk_daily", engine, if_exists="replace", index=False)
print("Uploaded features to Neon DB successfully ✅")
# Out:
# Uploaded features to Neon DB successfully ✅

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import average_precision_score, brier_score_loss
import numpy as np

X = features[["gdelt_tone_mean","gdelt_tone_std","port_congestion_z"]].values
y = features["label_bottleneck_next_14d"].values

tscv = TimeSeriesSplit(n_splits=3)
pr_aucs, briers = [], []

for tr, te in tscv.split(X):
    model = HistGradientBoostingClassifier(learning_rate=0.06)
    model.fit(X[tr], y[tr])
    p = model.predict_proba(X[te])[:,1]
    pr_aucs.append(average_precision_score(y[te], p))
    briers.append(brier_score_loss(y[te], p))

print("✅ Model trained successfully.")
print("Mean PR-AUC:", np.mean(pr_aucs))
print("Mean Brier score:", np.mean(briers))
# Out:
# ✅ Model trained successfully.
# Mean PR-AUC: 0.047619047619047616
# Mean Brier score: 0.06305460190213918
# C:\Users\SEC\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# C:\Users\SEC\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_ranking.py:1046: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(

# %%
p = model.predict_proba(X)[:,1]
out = pd.DataFrame({
    "ds": features["ds"],
    "risk_p": p,
    "expected_wait": np.clip(p*30, 4, 60)
})
out.to_sql("scores_daily", engine, if_exists="replace", index=False)
print("✅ Stored scores for dashboard!")
# Out:
# ✅ Stored scores for dashboard!

# %%
pd.read_sql("SELECT * FROM scores_daily LIMIT 5;", engine)
# Out:
#            ds    risk_p  expected_wait
# 0  2025-10-07  0.130435            4.0
# 1  2025-10-08  0.130435            4.0
# 2  2025-10-09  0.130435            4.0
# 3  2025-10-10  0.130435            4.0
# 4  2025-10-11  0.130435            4.0

# %%
MLFLOW_URI="https://dagshub.com/Yuvakrishna0/Supplychainprediction.mlflow/"

# %%
from sqlalchemy import create_engine, text

DATABASE_URL = "postgresql+psycopg2://neondb_owner:npg_k5JYXPoFzM1N@ep-wandering-salad-a1c7264o-pooler.ap-southeast-1.aws.neon.tech/neondb?sslmode=require"

engine = create_engine(DATABASE_URL)

with engine.connect() as conn:
    result = conn.execute(text("SELECT NOW();"))
    print(result.fetchone())
# Out:
# (datetime.datetime(2025, 11, 8, 12, 28, 18, 95017, tzinfo=datetime.timezone.utc),)

# %%
out.to_sql("scores_daily", engine, if_exists="replace", index=False)
print("✅ Stored scores for dashboard!")
# Out:
# ✅ Stored scores for dashboard!

# %%
out.to_sql("scores_daily", engine, if_exists="replace", index=False)
print("✅ Stored scores for dashboard!")

# %%
from sqlalchemy import create_engine, text

DATABASE_URL = "postgresql+psycopg2://neondb_owner:npg_k5JYXPoFzM1N@ep-wandering-salad-a1c7264o-pooler.ap-southeast-1.aws.neon.tech/neondb?sslmode=require"
engine = create_engine(DATABASE_URL)

with engine.connect() as conn:
    result = conn.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema='public';"))
    print([r[0] for r in result])
# Out:
# ['features_supply_risk_daily', 'scores_daily']

# %%
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime, timedelta
import numpy as np

# Connect to your Neon database
DATABASE_URL = "postgresql+psycopg2://neondb_owner:npg_k5JYXPoFzM1N@ep-wandering-salad-a1c7264o-pooler.ap-southeast-1.aws.neon.tech/neondb?sslmode=require"
engine = create_engine(DATABASE_URL)

# --- Generate realistic sample data for last 14 days ---
today = datetime.utcnow().date()
countries = ["USA", "IND", "CHN", "DEU", "BRA", "GBR", "AUS", "ZAF", "CAN"]
rows = []

for c in countries:
    for d in range(14):
        rows.append({
            "ActionGeo_CountryCode": c,
            "event_time": today - timedelta(days=d),
            "AvgTone": np.random.normal(0, 3),  # geopolitical sentiment
        })

df = pd.DataFrame(rows)

# --- Write it to Neon ---
df.to_sql("raw_events", engine, if_exists="replace", index=False)
print(f"✅ raw_events table created with {len(df)} rows")
# Out:
# C:\Users\SEC\AppData\Local\Temp\ipykernel_32740\4197946965.py:11: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow().date()
# ✅ raw_events table created with 126 rows

# %%
from sqlalchemy import text

with engine.connect() as conn:
    tables = conn.execute(text("SELECT table_name FROM information_schema.tables WHERE table_schema='public';"))
    print([r[0] for r in tables])
# Out:
# ['features_supply_risk_daily', 'scores_daily', 'raw_events']
